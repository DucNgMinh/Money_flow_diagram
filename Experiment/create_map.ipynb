# %%
import pandas as pd
import numpy as np
from unidecode import unidecode

# %%
df = pd.read_excel(r'C:\Users\Admin\PycharmProjects\Money_flow_diagram\Phân cấp OU.xlsx')
df.head(5)
# Out:
#    LEVEL_01_CODE LEVEL_01_NAME  LEVEL_02_CODE LEVEL_02_NAME  LEVEL_03_CODE  \
# 0              1   BIDV_REGION             50  HOI SO CHINH          10000
# 1              1   BIDV_REGION             50  HOI SO CHINH          10000
# 2              1   BIDV_REGION             50  HOI SO CHINH          10000
# 3              1   BIDV_REGION             50  HOI SO CHINH          10000
# 4              1   BIDV_REGION             50  HOI SO CHINH          10000
#
#      LEVEL_03_NAME  LEVEL_04_CODE LEVEL_04_NAME  LEVEL_05_CODE LEVEL_05_NAME  \
# 0  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 1  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 2  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 3  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 4  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
#
# ...

# %%
df.head()
# Out:
#    LEVEL_01_CODE LEVEL_01_NAME  LEVEL_02_CODE LEVEL_02_NAME  LEVEL_03_CODE  \
# 0              1   BIDV_REGION             50  HOI SO CHINH          10000
# 1              1   BIDV_REGION             50  HOI SO CHINH          10000
# 2              1   BIDV_REGION             50  HOI SO CHINH          10000
# 3              1   BIDV_REGION             50  HOI SO CHINH          10000
# 4              1   BIDV_REGION             50  HOI SO CHINH          10000
#
#      LEVEL_03_NAME  LEVEL_04_CODE LEVEL_04_NAME  LEVEL_05_CODE LEVEL_05_NAME  \
# 0  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 1  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 2  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 3  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 4  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
#
# ...

# %%
df.columns = ['LEVEL_01_CODE', 'LEVEL_01_NAME', 'LEVEL_02_CODE', 'LEVEL_02_NAME',
       'LEVEL_03_CODE', 'LEVEL_03_NAME', 'LEVEL_04_CODE', 'LEVEL_04_NAME',
       'LEVEL_05_CODE', 'LEVEL_05_NAME', 'LEVEL_06_CODE', 'LEVEL_06_NAME',
       'Ghi chú', 'Mã CRA', 'TÊN GỐC', 'mã 6 số', 'Loa (mã khối)', 'Tên khối',
       'Center (mã trung tâm)', 'Tên trung tâm']

# %%
df.isnull().sum()
# Out:
# LEVEL_01_CODE               0
# LEVEL_01_NAME               0
# LEVEL_02_CODE               0
# LEVEL_02_NAME               0
# LEVEL_03_CODE               0
# LEVEL_03_NAME               0
# LEVEL_04_CODE               0
# LEVEL_04_NAME               0
# LEVEL_05_CODE               0
# LEVEL_05_NAME               0
# LEVEL_06_CODE               0
# LEVEL_06_NAME               0
# Ghi chú                  3251
# Mã CRA                    248
# TÊN GỐC                  3070
# mã 6 số                   248
# Loa (mã khối)             248
# Tên khối                  251
# Center (mã trung tâm)     248
# Tên trung tâm             252
# dtype: int64

# %%
map_df = df[['LEVEL_01_CODE', 'LEVEL_01_NAME', 'LEVEL_02_CODE', 'LEVEL_02_NAME',
       'LEVEL_03_CODE', 'LEVEL_03_NAME', 'LEVEL_04_CODE', 'LEVEL_04_NAME',
       'LEVEL_05_CODE', 'LEVEL_05_NAME', 'LEVEL_06_CODE', 'LEVEL_06_NAME',
       'mã 6 số', 'TÊN GỐC', 'Loa (mã khối)', 'Tên khối',
       'Center (mã trung tâm)', 'Tên trung tâm']]
map_df
# Out:
#       LEVEL_01_CODE LEVEL_01_NAME  LEVEL_02_CODE            LEVEL_02_NAME  \
# 0                 1   BIDV_REGION             50             HOI SO CHINH
# 1                 1   BIDV_REGION             50             HOI SO CHINH
# 2                 1   BIDV_REGION             50             HOI SO CHINH
# 3                 1   BIDV_REGION             50             HOI SO CHINH
# 4                 1   BIDV_REGION             50             HOI SO CHINH
# ...             ...           ...            ...                      ...
# 3282              1   BIDV_REGION             58  DONG BANG SONG CUU LONG
# 3283              1   BIDV_REGION             58  DONG BANG SONG CUU LONG
# 3284              1   BIDV_REGION             58  DONG BANG SONG CUU LONG
# 3285              1   BIDV_REGION             59               NUOC NGOAI
# 3286              1   BIDV_REGION             59               NUOC NGOAI
#
#       LEVEL_03_CODE               LEVEL_03_NAME  LEVEL_04_CODE LEVEL_04_NAME  \
# ...

# %%
map_df.isnull().sum()
# Out:
# LEVEL_01_CODE               0
# LEVEL_01_NAME               0
# LEVEL_02_CODE               0
# LEVEL_02_NAME               0
# LEVEL_03_CODE               0
# LEVEL_03_NAME               0
# LEVEL_04_CODE               0
# LEVEL_04_NAME               0
# LEVEL_05_CODE               0
# LEVEL_05_NAME               0
# LEVEL_06_CODE               0
# LEVEL_06_NAME               0
# mã 6 số                   248
# TÊN GỐC                  3070
# Loa (mã khối)             248
# Tên khối                  251
# Center (mã trung tâm)     248
# Tên trung tâm             252
# dtype: int64

# %%
map_df.rename(columns={'mã 6 số': 'LEVEL_TEN_GOC_CODE', 'TÊN GỐC': 'LEVEL_TEN_GOC_NAME',
                       'Loa (mã khối)': 'LEVEL_KHOI_CODE', 'Tên khối': 'LEVEL_KHOI_NAME',
                       'Center (mã trung tâm)': 'LEVEL_TT_CODE', 'Tên trung tâm': 'LEVEL_TT_NAME'}, inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4700\455094826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_df.rename(columns={'mã 6 số': 'LEVEL_TEN_GOC_CODE', 'TÊN GỐC': 'LEVEL_TEN_GOC_NAME',

# %%
map_df.isnull().sum()
# Out:
# LEVEL_01_CODE            0
# LEVEL_01_NAME            0
# LEVEL_02_CODE            0
# LEVEL_02_NAME            0
# LEVEL_03_CODE            0
# LEVEL_03_NAME            0
# LEVEL_04_CODE            0
# LEVEL_04_NAME            0
# LEVEL_05_CODE            0
# LEVEL_05_NAME            0
# LEVEL_06_CODE            0
# LEVEL_06_NAME            0
# LEVEL_TEN_GOC_CODE     248
# LEVEL_TEN_GOC_NAME    3070
# LEVEL_KHOI_CODE        248
# LEVEL_KHOI_NAME        251
# LEVEL_TT_CODE          248
# LEVEL_TT_NAME          252
# dtype: int64

# %%
map_df['LEVEL_TEN_GOC_CODE'].fillna(99, inplace= True)
map_df['LEVEL_TEN_GOC_NAME'].fillna('UNALLOCABLE', inplace= True)
map_df['LEVEL_KHOI_CODE'].fillna(19, inplace= True)
map_df['LEVEL_KHOI_NAME'].fillna('BO PHAN CHUNG', inplace= True)
map_df['LEVEL_TT_CODE'].fillna(99, inplace= True)
map_df['LEVEL_TT_NAME'].fillna('UNALLOCABLE', inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4700\3852294980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_df['LEVEL_TEN_GOC_CODE'].fillna(99, inplace= True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4700\3852294980.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_df['LEVEL_TEN_GOC_NAME'].fillna('UNALLOCABLE', inplace= True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4700\3852294980.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
map_df.isnull().sum()
# Out:
# LEVEL_01_CODE         0
# LEVEL_01_NAME         0
# LEVEL_02_CODE         0
# LEVEL_02_NAME         0
# LEVEL_03_CODE         0
# LEVEL_03_NAME         0
# LEVEL_04_CODE         0
# LEVEL_04_NAME         0
# LEVEL_05_CODE         0
# LEVEL_05_NAME         0
# LEVEL_06_CODE         0
# LEVEL_06_NAME         0
# LEVEL_TEN_GOC_CODE    0
# LEVEL_TEN_GOC_NAME    0
# LEVEL_KHOI_CODE       0
# LEVEL_KHOI_NAME       0
# LEVEL_TT_CODE         0
# LEVEL_TT_NAME         0
# dtype: int64

# %%
map_df.head()
# Out:
#    LEVEL_01_CODE LEVEL_01_NAME  LEVEL_02_CODE LEVEL_02_NAME  LEVEL_03_CODE  \
# 0              1   BIDV_REGION             50  HOI SO CHINH          10000
# 1              1   BIDV_REGION             50  HOI SO CHINH          10000
# 2              1   BIDV_REGION             50  HOI SO CHINH          10000
# 3              1   BIDV_REGION             50  HOI SO CHINH          10000
# 4              1   BIDV_REGION             50  HOI SO CHINH          10000
#
#      LEVEL_03_NAME  LEVEL_04_CODE LEVEL_04_NAME  LEVEL_05_CODE LEVEL_05_NAME  \
# 0  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 1  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 2  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 3  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
# 4  HOI SO CHINH_L3           1000           HSC             71       TT CNTT
#
# ...

# %%
map_df['LEVEL_TEN_GOC_NAME'] = map_df['LEVEL_TEN_GOC_NAME'].apply(unidecode).str.upper()
map_df['LEVEL_TEN_GOC_NAME'].head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4700\226321053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_df['LEVEL_TEN_GOC_NAME'] = map_df['LEVEL_TEN_GOC_NAME'].apply(unidecode).str.upper()
# 0       UNALLOCABLE
# 1    TRUNG TAM CNTT
# 2    TRUNG TAM CNTT
# 3    TRUNG TAM CNTT
# 4    TRUNG TAM CNTT
# Name: LEVEL_TEN_GOC_NAME, dtype: object

# %%
map_df.to_csv('map_all.csv', index= False)

# %%
test_map = map_df

# %%
df_color_1 = pd.read_csv('./Map/ColorMap.csv')
df_color_1['TÊN GỐC'] = df_color_1['TÊN GỐC'].apply(unidecode).str.upper()
df_color_1.head()
# Out:
#                        TÊN GỐC      Màu
# 0           BAN QUAN LY DAU TU  #FFD1DC
# 1            BAN TAI TRO DU AN  #77DD77
# 2  BAN KHACH HANG DOANH NGHIEP  #77DD77
# 3       BAN DINH CHE TAI CHINH  #77DD77
# 4            BAN TAI TRO DU AN  #77DD77

# %%
df_color_2 = pd.read_csv('./Map/ColorMapV2.csv')
df_color_2['Tên khối'] = df_color_2['Tên khối'].apply(unidecode).str.upper()
df_color_2.head()
# Out:
#         Tên khối      Màu
# 0    KHOI DAU TU  #FFD1DC
# 1    KHOI DAU TU  #FFD1DC
# 2  KHOI BAN BUON  #77DD77
# 3  KHOI BAN BUON  #77DD77
# 4  KHOI BAN BUON  #77DD77

# %%
df_color_3 = pd.read_csv('./Map/ColorMapV3.csv')
df_color_3['Tên trung tâm'] = df_color_3['Tên trung tâm'].apply(unidecode).str.upper()
df_color_3.head()
# Out:
#                        Tên trung tâm      Màu
# 0                       TRUNG TAM AO  #77DD77
# 1                TRUNG TAM DOANH THU  #89CFF0
# 2          TRUNG TAM HO TRO SAN PHAM  #B39EB5
# 3         TRUNG TAM HO TRO TRUC TIEP  #FDFD96
# 4  TRUNG TAM QUAN LY CHUNG CHI NHANH  #FFB347

# %%
test_map['LEVEL_TEN_GOC_COLOR'] = test_map['LEVEL_TEN_GOC_NAME'].map(df_color_1.set_index('TÊN GỐC')['Màu'].to_dict())
test_map['LEVEL_TEN_GOC_COLOR'].value_counts(dropna= False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4700\2010536619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_map['LEVEL_TEN_GOC_COLOR'] = test_map['LEVEL_TEN_GOC_NAME'].map(df_color_1.set_index('TÊN GỐC')['Màu'].to_dict())
# NaN        3118
# #89CFF0      34
# #77DD77      32
# #CBF3D2      22
# #FFB347      15
# #D1E8E2      12
# #B39EB5       8
# #FFE5B4       8
# #FF6961       8
# #CB99C9       8
# #FDFD96       6
# #ECC8EC       6
# #B0E0E6       4
# #FAD5A5       4
# #FFD1DC       2
# Name: LEVEL_TEN_GOC_COLOR, dtype: int64

# %%
test_map['LEVEL_KHOI_COLOR'] = test_map['LEVEL_KHOI_NAME'].map(df_color_2.set_index('Tên khối')['Màu'].to_dict())
test_map['LEVEL_KHOI_COLOR'].value_counts(dropna= False)
# Out:
# #89CFF0    1208
# #FFB347     465
# #CFCFC4     460
# #77DD77     364
# #CBF3D2     273
# #FF6961     197
# #FDFD96     193
# #ECC8EC      83
# #D1E8E2      12
# #B39EB5       9
# #CB99C9       8
# #FFE5B4       4
# #B0E0E6       4
# #FAD5A5       4
# #FFD1DC       3
# Name: LEVEL_KHOI_COLOR, dtype: int64

# %%
test_map['LEVEL_TT_COLOR'] = test_map['LEVEL_TT_NAME'].map(df_color_3.set_index('Tên trung tâm')['Màu'].to_dict())
test_map['LEVEL_TT_COLOR'].value_counts(dropna= False)
# Out:
# #89CFF0    1518
# #FDFD96     586
# #FFB347     512
# #B39EB5     279
# #77DD77     217
# NaN         155
# #ECC8EC      20
# Name: LEVEL_TT_COLOR, dtype: int64

# %%
test_map['LEVEL_TEN_GOC_COLOR'].fillna('#B39EB5', inplace= True)
test_map['LEVEL_KHOI_COLOR'].fillna('#B39EB5', inplace= True)
test_map['LEVEL_TT_COLOR'].fillna('#B39EB5', inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4700\1871220170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_map['LEVEL_TEN_GOC_COLOR'].fillna('#B39EB5', inplace= True)

# %%
test_map
# Out:
#       LEVEL_01_CODE LEVEL_01_NAME  LEVEL_02_CODE            LEVEL_02_NAME  \
# 0                 1   BIDV_REGION             50             HOI SO CHINH
# 1                 1   BIDV_REGION             50             HOI SO CHINH
# 2                 1   BIDV_REGION             50             HOI SO CHINH
# 3                 1   BIDV_REGION             50             HOI SO CHINH
# 4                 1   BIDV_REGION             50             HOI SO CHINH
# ...             ...           ...            ...                      ...
# 3282              1   BIDV_REGION             58  DONG BANG SONG CUU LONG
# 3283              1   BIDV_REGION             58  DONG BANG SONG CUU LONG
# 3284              1   BIDV_REGION             58  DONG BANG SONG CUU LONG
# 3285              1   BIDV_REGION             59               NUOC NGOAI
# 3286              1   BIDV_REGION             59               NUOC NGOAI
#
#       LEVEL_03_CODE               LEVEL_03_NAME  LEVEL_04_CODE LEVEL_04_NAME  \
# ...

# %%
test_map.isnull().sum()
# Out:
# LEVEL_01_CODE          0
# LEVEL_01_NAME          0
# LEVEL_02_CODE          0
# LEVEL_02_NAME          0
# LEVEL_03_CODE          0
# LEVEL_03_NAME          0
# LEVEL_04_CODE          0
# LEVEL_04_NAME          0
# LEVEL_05_CODE          0
# LEVEL_05_NAME          0
# LEVEL_06_CODE          0
# LEVEL_06_NAME          0
# LEVEL_TEN_GOC_CODE     0
# LEVEL_TEN_GOC_NAME     0
# LEVEL_KHOI_CODE        0
# LEVEL_KHOI_NAME        0
# LEVEL_TT_CODE          0
# LEVEL_TT_NAME          0
# LEVEL_TEN_GOC_COLOR    0
# LEVEL_KHOI_COLOR       0
# LEVEL_TT_COLOR         0
# dtype: int64

# %%
test_map.columns
# Out:
# Index(['LEVEL_01_CODE', 'LEVEL_01_NAME', 'LEVEL_02_CODE', 'LEVEL_02_NAME',
#        'LEVEL_03_CODE', 'LEVEL_03_NAME', 'LEVEL_04_CODE', 'LEVEL_04_NAME',
#        'LEVEL_05_CODE', 'LEVEL_05_NAME', 'LEVEL_06_CODE', 'LEVEL_06_NAME',
#        'LEVEL_TEN_GOC_CODE', 'LEVEL_TEN_GOC_NAME', 'LEVEL_KHOI_CODE',
#        'LEVEL_KHOI_NAME', 'LEVEL_TT_CODE', 'LEVEL_TT_NAME',
#        'LEVEL_TEN_GOC_COLOR', 'LEVEL_KHOI_COLOR', 'LEVEL_TT_COLOR'],
#       dtype='object')

# %%
test_map = test_map[['LEVEL_01_CODE', 'LEVEL_01_NAME', 'LEVEL_02_CODE', 'LEVEL_02_NAME',
       'LEVEL_03_CODE', 'LEVEL_03_NAME', 'LEVEL_04_CODE', 'LEVEL_04_NAME',
       'LEVEL_05_CODE', 'LEVEL_05_NAME', 'LEVEL_06_CODE', 'LEVEL_06_NAME',
       'LEVEL_TEN_GOC_CODE', 'LEVEL_TEN_GOC_NAME', 'LEVEL_TEN_GOC_COLOR',
       'LEVEL_TT_CODE', 'LEVEL_TT_NAME', 'LEVEL_TT_COLOR',
       'LEVEL_KHOI_CODE', 'LEVEL_KHOI_NAME', 'LEVEL_KHOI_COLOR']]

# %%
test_map.to_csv('MapV1.csv', index= False)

# %%
df = pd.read_excel('./Real-data/2023-12-13 Cây phân cấp phục vụ phân bổ Sanky Chart.xlsx', sheet_name= 'Product_Hierarchy final to FIS')
df

# %%
df['LEVEL2_ID'].value_counts()

# %%
color_sp_df_1 = pd.DataFrame([[20,'#CBF3D2'],
[21,'#FFE5B4'],
[22,'#CFCFC4'],
[23,'#FF6961'],
[24,'#B0E0E6'],
[25,'#CB99C9'],
[26,'#D1E8E2'],
[27,'#FAD5A5'],
[28,'#89CFF0'],
[29,'#B39EB5'],
[91,'#FFD1DC']], columns=['TEN_SP', 'Màu'])

# %%
df['LEVEL2_COLOR'] = df['LEVEL2_ID'].map(color_sp_df_1.set_index('TEN_SP')['Màu'].to_dict())
df['LEVEL2_COLOR'].value_counts(dropna= False)

# %%
df.to_csv('Map_SP_PK_V1.csv', index= False)
